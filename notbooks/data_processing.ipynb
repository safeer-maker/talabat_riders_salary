# %%
import os
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
data = pd.ExcelFile ("data/TB 12_2024.xlsx")

# %%
data

# %%
sheets_name  = data.sheet_names
sheets_name
# Out:
# ['DV',
#  'Summary',
#  'Salary Entry',
#  'Salary Status (Aqib & Afaq)',
#  'Less Orders (Penalty)',
#  'Performance Ded (Mr. Afaq)',
#  'Account Reconciliation',
#  'Slips PDF',
#  'Deduction (Mr.Aqib)',
#  'Payables',
#  'C3Pay Cardholders',
#  'Proactive Deduction',
#  'Payrolls on hold',
#  'Cash Payroll',
#  'Negative Payroll',
#  'Summary01',
#  'Active Accounts',
#  'data-analyticskiste-emailschedu',
#  'Passport (Log)',
#  'DC (Log)',
#  'Traffic Violatons',
#  '(-) Adjustments',
#  'Compliance',
#  'Salik Account',
#  'Bike Fine',
#  'Fleet Data',
#  'Etisalat Bills',
#  'Liabilty',
#  'T-COD & Clawback-AED',
#  'T-Payroll',
#  'T-Inventory Deductions',
#  'T-Clawback(details)',
#  'T-Incentives',
#  'Invoice (TB 12-24)',
#  'Sheet40',
#  'Fine']

# %%
for sheet in sheets_name:
    print(sheet)
    print(data.parse(sheet).head(10))
    print("\n\n")
# Out:
# DV
#       Salrary Source     Client     Company       City  \
# 0  C3Pay Cardholders    Talabat    Eltohamy      Dubai
# 1               Cash       Noon  Fast Rider    Sharjah
# 2                NaN  Deliveroo         NaN        RAK
# 3                NaN        NaN         NaN     Al Ain
# 4                NaN        NaN         NaN  Abu Dhabi
# 5                NaN        NaN         NaN      Ajman
# 6                NaN        NaN         NaN        NaN
# 7                NaN        NaN         NaN        NaN
# 8                NaN        NaN         NaN        NaN
# 9                NaN        NaN         NaN        NaN
#
#                            Salary Status
# 0                              Processed
# 1                                On Hold
# 2           On Hold/Due To Legal Doc Exp
# 3                On Hold/Low Performance
# 4  On Hold/ Need To Fix Pending Accounts
# 5     On Hold/Need to Visit Office First
# 6     On Hold/Need Submit Legal Document
# ...

# %%
df = data.parse('Salary Entry').drop
df
# Out:
#         SEQ Unnamed: 1                                         Unnamed: 2  \
# 0         1          2                                                  3
# 1    ELT ID         ID                                      Employee Name
# 2     R1530     797885                  Muhammad Shahbaz Muhammad Hussain
# 3     R1507    1570655  Syed Luqman Mustafa Shah Syed Ghulam Mustafa Shah
# 4     R1517     665392                      Muhammad Awais Muhammad Anwar
# ..      ...        ...                                                ...
# 322   R1743    2071919                             Bilal Ahmad Rang Elahi
# 323   R1978    2499140                               Luqman Saif Saif Ali
# 324   R1750    2088738                          Farman Ali Muhammad Irfan
# 325   R1969    1578759                    Muhammad Hamdan Muhammad Sultan
# 326   R1959    1587851                              Ali Raza Bashir Ahmad
#
#             Unnamed: 3    Unnamed: 4 Unnamed: 5           Unnamed: 6  \
# ...
